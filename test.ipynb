# %%
from litrev import LitRev as Lr
import pandas as pd

# %%
df = pd.read_csv("export2022.12.02-16.15.50.csv")

# %%
drop_terms = ['covid', 'deep', 'machine', 'feature', 'pandemic', 'data']

# %%
covid_lit = Lr(df, year_start=2020, drop_values=drop_terms)

# %%
covid_lit.plot_common_terms()
# Out:
# C:\Users\karatd\PycharmProjects\litrev\litrev.py:102: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.relplot(x="Count", y="Term", size="Citations",

# %%
covid_lit.plot_most_cited()
# Out:
# C:\Users\karatd\PycharmProjects\litrev\litrev.py:123: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   self.top_counts.sort_values(by='Citations', ascending=False)['Term'][:self.top_citations])]
