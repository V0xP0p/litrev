# %%
from litrev import LitRev as Lr
import pandas as pd

# %%
df = pd.read_csv("export2022.12.02-16.15.50.csv")

# %%
covid_lit = Lr(df, year_start=2020)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 covid_lit = LR(df, year_start=2020)
#
# File G:\My Drive\Education\MSc Biomedical Engineering\Medical Physics, imaging and image processing\pythonProject\litrev.py:24, in LitRev.__init__(self, df, year_start, year_end, drop_values, top_count, top_citations)
#      22 self.drop_vals = drop_values
#      23 # Split list terms, merge and expand the dataframe
# ---> 24 self.lit = self.term_split(self.input, self.drop_vals)
#      25 self.year_start = year_start
#      26 self.year_end = year_end
#
# File G:\My Drive\Education\MSc Biomedical Engineering\Medical Physics, imaging and image processing\pythonProject\litrev.py:38, in LitRev.term_split(df, drop_values)
#      33 @staticmethod
#      34 def term_split(df,
#      35                drop_values):
# ...
